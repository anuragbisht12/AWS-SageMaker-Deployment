# %% [markdown]
# # Movie recommendation on Amazon SageMaker with Factorization Machines

# %% [markdown]
# ### 1.Download the dataset

# %%
# !wget http://files.grouplens.org/datasets/movielens/ml-100k.zip
# !unzip -o ml-100k.zip
# Out:
# --2020-10-10 10:06:23--  http://files.grouplens.org/datasets/movielens/ml-100k.zip
# Resolving files.grouplens.org (files.grouplens.org)... 128.101.65.152
# Connecting to files.grouplens.org (files.grouplens.org)|128.101.65.152|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4924029 (4.7M) [application/zip]
# Saving to: ‘ml-100k.zip’
#
# ml-100k.zip         100%[===================>]   4.70M  6.32MB/s    in 0.7s
#
# 2020-10-10 10:06:24 (6.32 MB/s) - ‘ml-100k.zip’ saved [4924029/4924029]
#
# Archive:  ml-100k.zip
#    creating: ml-100k/
#   inflating: ml-100k/allbut.pl
#   inflating: ml-100k/mku.sh
#   inflating: ml-100k/README
#   inflating: ml-100k/u.data
#   inflating: ml-100k/u.genre
#   inflating: ml-100k/u.info
#   inflating: ml-100k/u.item
#   inflating: ml-100k/u.occupation
#   inflating: ml-100k/u.user
#   inflating: ml-100k/u1.base
#   inflating: ml-100k/u1.test
#   inflating: ml-100k/u2.base
#   inflating: ml-100k/u2.test
#   inflating: ml-100k/u3.base
#   inflating: ml-100k/u3.test
#   inflating: ml-100k/u4.base
#   inflating: ml-100k/u4.test
#   inflating: ml-100k/u5.base
#   inflating: ml-100k/u5.test
#   inflating: ml-100k/ua.base
#   inflating: ml-100k/ua.test
#   inflating: ml-100k/ub.base
#   inflating: ml-100k/ub.test

# %% [markdown]
# ### 2.Inspect the dataset

# %%
# %cd ml-100k
# !shuf ua.base -o ua.base.shuffled
# !head -10 ua.base.shuffled
# Out:
# /home/ec2-user/SageMaker/dlnotebooks/sagemaker/ml-100k
# 499	87	4	885599598
# 30	259	4	875058280
# 298	485	3	884124993
# 146	315	5	891458193
# 910	3	2	881421019
# 851	8	4	875731776
# 440	198	4	891577843
# 254	136	4	886471695
# 10	127	5	877886661
# 622	173	5	882670057

# %%
# !head -10 ua.test
# Out:
# 1	20	4	887431883
# 1	33	4	878542699
# 1	61	4	878542420
# 1	117	3	874965739
# 1	155	2	878542201
# 1	160	4	875072547
# 1	171	5	889751711
# 1	189	3	888732928
# 1	202	5	875072442
# 1	265	4	878542441

# %%
import sagemaker
import sagemaker.amazon.common as smac
from sagemaker import get_execution_role
from sagemaker.predictor import json_deserializer

import boto3, csv, io, json
import numpy as np
from scipy.sparse import lil_matrix
# Out:
# No handlers could be found for logger "sagemaker"

# %% [markdown]
# ### 3. Build training set and test set

# %%
nbUsers=943
nbMovies=1682
nbFeatures=nbUsers+nbMovies

nbRatingsTrain=90570
nbRatingsTest=9430

# %%
# For each user, build a list of rated movies.
# We'd need this to add random negative samples.
moviesByUser = {}
for userId in range(nbUsers):
    moviesByUser[str(userId)]=[]
 
with open('ua.base.shuffled','r') as f:
    samples=csv.reader(f,delimiter='\t')
    for userId,movieId,rating,timestamp in samples:
        moviesByUser[str(int(userId)-1)].append(int(movieId)-1)

# %%
def loadDataset(filename, lines, columns):
    # Features are one-hot encoded in a sparse matrix
    X = lil_matrix((lines, columns)).astype('float32')
    # Labels are stored in a vector
    Y = []
    line=0
    with open(filename,'r') as f:
        samples=csv.reader(f,delimiter='\t')
        for userId,movieId,rating,timestamp in samples:
            X[line,int(userId)-1] = 1
            X[line,int(nbUsers)+int(movieId)-1] = 1
            if int(rating) >= 4:
                Y.append(1)
            else:
                Y.append(0)
            line=line+1
            
    Y=np.array(Y).astype('float32')
    return X,Y

# %%
X_train, Y_train = loadDataset('ua.base.shuffled', nbRatingsTrain, nbFeatures)
X_test, Y_test = loadDataset('ua.test',nbRatingsTest,nbFeatures)

# %%
print(X_train.shape)
print(Y_train.shape)
assert X_train.shape == (nbRatingsTrain, nbFeatures)
assert Y_train.shape == (nbRatingsTrain, )
zero_labels = np.count_nonzero(Y_train)
print("Training labels: %d zeros, %d ones" % (zero_labels, nbRatingsTrain-zero_labels))

print(X_test.shape)
print(Y_test.shape)
assert X_test.shape  == (nbRatingsTest, nbFeatures)
assert Y_test.shape  == (nbRatingsTest, )
zero_labels = np.count_nonzero(Y_test)
print("Test labels: %d zeros, %d ones" % (zero_labels, nbRatingsTest-zero_labels))
# Out:
# (90570, 2625)
# (90570,)
# Training labels: 49906 zeros, 40664 ones
# (9430, 2625)
# (9430,)
# Test labels: 5469 zeros, 3961 ones

# %% [markdown]
# ### 4. Convert to protobuf and save to S3

# %%
bucket = 'movierecommendationdemo1'
prefix = 'sagemaker/fm-movielens'

train_key      = 'train.protobuf'
train_prefix   = '{}/{}'.format(prefix, 'train3')

test_key       = 'test.protobuf'
test_prefix    = '{}/{}'.format(prefix, 'test3')

output_prefix  = 's3://{}/{}/output'.format(bucket, prefix)

# %%
def writeDatasetToProtobuf(X, Y, bucket, prefix, key):
    buf = io.BytesIO()
    smac.write_spmatrix_to_sparse_tensor(buf, X, Y)
    buf.seek(0)
    obj = '{}/{}'.format(prefix, key)
    boto3.resource('s3').Bucket(bucket).Object(obj).upload_fileobj(buf)
    return 's3://{}/{}'.format(bucket,obj)
    
train_data = writeDatasetToProtobuf(X_train, Y_train, bucket, train_prefix, train_key)    
test_data  = writeDatasetToProtobuf(X_test, Y_test, bucket, test_prefix, test_key)    
  
print(train_data)
print(test_data)
print('Output: {}'.format(output_prefix))
# Out:
# s3://movierecommendationdemo/sagemaker/fm-movielens/train3/train.protobuf
# s3://movierecommendationdemo/sagemaker/fm-movielens/test3/test.protobuf
# Output: s3://movierecommendationdemo/sagemaker/fm-movielens/output

# %%
# train_data='s3://movierecommendationdemo1/sagemaker/fm-movielens/train3/train.protobuf'
# test_data='s3://movierecommendationdemo1/sagemaker/fm-movielens/test3/test.protobuf'
# output_prefix='s3://movierecommendationdemo1/sagemaker/fm-movielens/output'

# %% [markdown]
# ### 5. Run training job

# %%
containers = {'us-west-2': '174872318107.dkr.ecr.us-west-2.amazonaws.com/factorization-machines:latest',
              'us-east-1': '382416733822.dkr.ecr.us-east-1.amazonaws.com/factorization-machines:latest',
              'us-east-2': '404615174143.dkr.ecr.us-east-2.amazonaws.com/factorization-machines:latest',
              'eu-west-1': '438346466558.dkr.ecr.eu-west-1.amazonaws.com/factorization-machines:latest'}

# %%
fm = sagemaker.estimator.Estimator(containers[boto3.Session().region_name],
                                   get_execution_role(), 
                                   train_instance_count=1, 
                                   train_instance_type='ml.m4.xlarge',
                                   output_path=output_prefix,
                                   sagemaker_session=sagemaker.Session())

fm.set_hyperparameters(feature_dim=nbFeatures,
                      predictor_type='binary_classifier',
                      mini_batch_size=1000,
                      num_factors=64,
                      epochs=100)

fm.fit({'train': train_data, 'test': test_data})
# Out:
# 2020-10-10 11:33:18 Starting - Starting the training job...
# 2020-10-10 11:33:21 Starting - Launching requested ML instances......
# 2020-10-10 11:34:24 Starting - Preparing the instances for training......
# 2020-10-10 11:35:40 Downloading - Downloading input data
# 2020-10-10 11:35:40 Training - Downloading the training image..Docker entrypoint called with argument(s): train
# Running default environment configuration script
# /opt/amazon/lib/python2.7/site-packages/pandas/util/nosetester.py:13: DeprecationWarning: Importing from numpy.testing.nosetester is deprecated, import from numpy.testing instead.
#   from numpy.testing import nosetester
# [10/10/2020 11:36:03 INFO 140298610640704] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-conf.json: {u'factors_lr': u'0.0001', u'linear_init_sigma': u'0.01', u'epochs': 1, u'_wd': u'1.0', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'factors_init_sigma': u'0.001', u'_log_level': u'info', u'bias_init_method': u'normal', u'linear_init_method': u'normal', u'linear_lr': u'0.001', u'factors_init_method': u'normal', u'_tuning_objective_metric': u'', u'bias_wd': u'0.01', u'use_linear': u'true', u'bias_lr': u'0.1', u'mini_batch_size': u'1000', u'_use_full_symbolic': u'true', u'batch_metrics_publish_interval': u'500', u'bias_init_sigma': u'0.01', u'_num_gpus': u'auto', u'_data_format': u'record', u'factors_wd': u'0.00001', u'linear_wd': u'0.001', u'_kvstore': u'auto', u'_learning_rate': u'1.0', u'_optimizer': u'adam'}
# [10/10/2020 11:36:03 INFO 140298610640704] Reading provided configuration from /opt/ml/input/config/hyperparameters.json: {u'epochs': u'100', u'feature_dim': u'2625', u'mini_batch_size': u'1000', u'predictor_type': u'binary_classifier', u'num_factors': u'64'}
# [10/10/2020 11:36:03 INFO 140298610640704] Final configuration: {u'factors_lr': u'0.0001', u'linear_init_sigma': u'0.01', u'epochs': u'100', u'feature_dim': u'2625', u'num_factors': u'64', u'_wd': u'1.0', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'factors_init_sigma': u'0.001', u'_log_level': u'info', u'bias_init_method': u'normal', u'linear_init_method': u'normal', u'linear_lr': u'0.001', u'factors_init_method': u'normal', u'_tuning_objective_metric': u'', u'bias_wd': u'0.01', u'use_linear': u'true', u'bias_lr': u'0.1', u'mini_batch_size': u'1000', u'_use_full_symbolic': u'true', u'batch_metrics_publish_interval': u'500', u'predictor_type': u'binary_classifier', u'bias_init_sigma': u'0.01', u'_num_gpus': u'auto', u'_data_format': u'record', u'factors_wd': u'0.00001', u'linear_wd': u'0.001', u'_kvstore': u'auto', u'_learning_rate': u'1.0', u'_optimizer': u'adam'}
# [10/10/2020 11:36:03 WARNING 140298610640704] Loggers have already been setup.
# Process 1 is a worker.
# [10/10/2020 11:36:03 INFO 140298610640704] Using default worker.
# [2020-10-10 11:36:03.626] [tensorio] [warning] TensorIO is already initialized; ignoring the initialization routine.
# [2020-10-10 11:36:03.631] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 10, "num_examples": 1, "num_bytes": 64000}
# [10/10/2020 11:36:03 INFO 140298610640704] nvidia-smi took: 0.0251829624176 secs to identify 0 gpus
# [10/10/2020 11:36:03 INFO 140298610640704] Number of GPUs being used: 0
# [10/10/2020 11:36:03 INFO 140298610640704] [Sparse network] Building a sparse network.
# [10/10/2020 11:36:03 INFO 140298610640704] Create Store: local
# #metrics {"Metrics": {"initialize.time": {"count": 1, "max": 35.83192825317383, "sum": 35.83192825317383, "min": 35.83192825317383}}, "EndTime": 1602329763.666063, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1602329763.620799}
#
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Total Records Seen": {"count": 1, "max": 1000, "sum": 1000.0, "min": 1000}, "Max Records Seen Between Resets": {"count": 1, "max": 1000, "sum": 1000.0, "min": 1000}, "Reset Count": {"count": 1, "max": 1, "sum": 1.0, "min": 1}}, "EndTime": 1602329763.666285, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1602329763.66622}
#
# [11:36:03] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.1.x.203343.0/AL2012/generic-flavor/src/src/kvstore/./kvstore_local.h:280: Warning: non-default weights detected during kvstore pull. This call has been ignored. Please make sure to use row_sparse_pull with row_ids.
# [11:36:03] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.1.x.203343.0/AL2012/generic-flavor/src/src/kvstore/./kvstore_local.h:280: Warning: non-default weights detected during kvstore pull. This call has been ignored. Please make sure to use row_sparse_pull with row_ids.
# [10/10/2020 11:36:03 INFO 140298610640704] #quality_metric: host=algo-1, epoch=0, batch=0 train binary_classification_accuracy <score>=0.55
# [10/10/2020 11:36:03 INFO 140298610640704] #quality_metric: host=algo-1, epoch=0, batch=0 train binary_classification_cross_entropy <loss>=0.69190612793
# [10/10/2020 11:36:03 INFO 140298610640704] #quality_metric: host=algo-1, epoch=0, batch=0 train binary_f_1.000 <score>=0.702380952381
# [2020-10-10 11:36:04.497] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 2, "duration": 810, "num_examples": 91, "num_bytes": 5796480}
# [10/10/2020 11:36:04 INFO 140298610640704] #quality_metric: host=algo-1, epoch=0, train binary_classification_accuracy <score>=0.548263736264
# [10/10/2020 11:36:04 INFO 140298610640704] #quality_metric: host=algo-1, epoch=0, train binary_classification_cross_entropy <loss>=0.683761001084
# [10/10/2020 11:36:04 INFO 140298610640704] #quality_metric: host=algo-1, epoch=0, train binary_f_1.000 <score>=0.708126837165
# #metrics {"Metrics": {"epochs": {"count": 1, "max": 100, "sum": 100.0, "min": 100}, "update.time": {"count": 1, "max": 831.8920135498047, "sum": 831.8920135498047, "min": 831.8920135498047}}, "EndTime": 1602329764.498421, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1602329763.666145}
#
# [10/10/2020 11:36:04 INFO 140298610640704] #progress_metric: host=algo-1, completed 1 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Batches Since Last Reset": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Records Since Last Reset": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Total Batches Seen": {"count": 1, "max": 92, "sum": 92.0, "min": 92}, "Total Records Seen": {"count": 1, "max": 91570, "sum": 91570.0, "min": 91570}, "Max Records Seen Between Resets": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Reset Count": {"count": 1, "max": 2, "sum": 2.0, "min": 2}}, "EndTime": 1602329764.498736, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 0}, "StartTime": 1602329763.666491}
#
# [10/10/2020 11:36:04 INFO 140298610640704] #throughput_metric: host=algo-1, train throughput=108804.667408 records/second
# [10/10/2020 11:36:04 INFO 140298610640704] #quality_metric: host=algo-1, epoch=1, batch=0 train binary_classification_accuracy <score>=0.688
# [10/10/2020 11:36:04 INFO 140298610640704] #quality_metric: host=algo-1, epoch=1, batch=0 train binary_classification_cross_entropy <loss>=0.679086791992
# [10/10/2020 11:36:04 INFO 140298610640704] #quality_metric: host=algo-1, epoch=1, batch=0 train binary_f_1.000 <score>=0.770588235294
# [2020-10-10 11:36:05.335] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 4, "duration": 834, "num_examples": 91, "num_bytes": 5796480}
# [10/10/2020 11:36:05 INFO 140298610640704] #quality_metric: host=algo-1, epoch=1, train binary_classification_accuracy <score>=0.563120879121
# [10/10/2020 11:36:05 INFO 140298610640704] #quality_metric: host=algo-1, epoch=1, train binary_classification_cross_entropy <loss>=0.673871860378
# [10/10/2020 11:36:05 INFO 140298610640704] #quality_metric: host=algo-1, epoch=1, train binary_f_1.000 <score>=0.710806564246
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 836.982011795044, "sum": 836.982011795044, "min": 836.982011795044}}, "EndTime": 1602329765.336529, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1602329764.498526}
#
# [10/10/2020 11:36:05 INFO 140298610640704] #progress_metric: host=algo-1, completed 2 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Batches Since Last Reset": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Records Since Last Reset": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Total Batches Seen": {"count": 1, "max": 183, "sum": 183.0, "min": 183}, "Total Records Seen": {"count": 1, "max": 182140, "sum": 182140.0, "min": 182140}, "Max Records Seen Between Resets": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Reset Count": {"count": 1, "max": 3, "sum": 3.0, "min": 3}}, "EndTime": 1602329765.336759, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 1}, "StartTime": 1602329764.49951}
#
# [10/10/2020 11:36:05 INFO 140298610640704] #throughput_metric: host=algo-1, train throughput=108158.512537 records/second
# [10/10/2020 11:36:05 INFO 140298610640704] #quality_metric: host=algo-1, epoch=2, batch=0 train binary_classification_accuracy <score>=0.708
# [10/10/2020 11:36:05 INFO 140298610640704] #quality_metric: host=algo-1, epoch=2, batch=0 train binary_classification_cross_entropy <loss>=0.667176513672
# [10/10/2020 11:36:05 INFO 140298610640704] #quality_metric: host=algo-1, epoch=2, batch=0 train binary_f_1.000 <score>=0.784342688331
# [2020-10-10 11:36:06.240] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 6, "duration": 901, "num_examples": 91, "num_bytes": 5796480}
# [10/10/2020 11:36:06 INFO 140298610640704] #quality_metric: host=algo-1, epoch=2, train binary_classification_accuracy <score>=0.596516483516
# [10/10/2020 11:36:06 INFO 140298610640704] #quality_metric: host=algo-1, epoch=2, train binary_classification_cross_entropy <loss>=0.664331247183
# [10/10/2020 11:36:06 INFO 140298610640704] #quality_metric: host=algo-1, epoch=2, train binary_f_1.000 <score>=0.725519365473
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 904.088020324707, "sum": 904.088020324707, "min": 904.088020324707}}, "EndTime": 1602329766.241509, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1602329765.336609}
#
# [10/10/2020 11:36:06 INFO 140298610640704] #progress_metric: host=algo-1, completed 3 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Batches Since Last Reset": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Records Since Last Reset": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Total Batches Seen": {"count": 1, "max": 274, "sum": 274.0, "min": 274}, "Total Records Seen": {"count": 1, "max": 272710, "sum": 272710.0, "min": 272710}, "Max Records Seen Between Resets": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Reset Count": {"count": 1, "max": 4, "sum": 4.0, "min": 4}}, "EndTime": 
"Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 97}, "StartTime": 1602329830.072249}
#
# [10/10/2020 11:37:10 INFO 140298610640704] #throughput_metric: host=algo-1, train throughput=137085.229516 records/second
# [10/10/2020 11:37:10 INFO 140298610640704] #quality_metric: host=algo-1, epoch=98, batch=0 train binary_classification_accuracy <score>=0.751
# [10/10/2020 11:37:10 INFO 140298610640704] #quality_metric: host=algo-1, epoch=98, batch=0 train binary_classification_cross_entropy <loss>=0.525248535156
# [10/10/2020 11:37:10 INFO 140298610640704] #quality_metric: host=algo-1, epoch=98, batch=0 train binary_f_1.000 <score>=0.778666666667
# [2020-10-10 11:37:11.376] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 198, "duration": 641, "num_examples": 91, "num_bytes": 5796480}
# [10/10/2020 11:37:11 INFO 140298610640704] #quality_metric: host=algo-1, epoch=98, train binary_classification_accuracy <score>=0.748054945055
# [10/10/2020 11:37:11 INFO 140298610640704] #quality_metric: host=algo-1, epoch=98, train binary_classification_cross_entropy <loss>=0.514959945846
# [10/10/2020 11:37:11 INFO 140298610640704] #quality_metric: host=algo-1, epoch=98, train binary_f_1.000 <score>=0.77812938501
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 643.916130065918, "sum": 643.916130065918, "min": 643.916130065918}}, "EndTime": 1602329831.377353, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1602329830.732607}
#
# [10/10/2020 11:37:11 INFO 140298610640704] #progress_metric: host=algo-1, completed 99 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Batches Since Last Reset": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Records Since Last Reset": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Total Batches Seen": {"count": 1, "max": 9010, "sum": 9010.0, "min": 9010}, "Total Records Seen": {"count": 1, "max": 8967430, "sum": 8967430.0, "min": 8967430}, "Max Records Seen Between Resets": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Reset Count": {"count": 1, "max": 100, "sum": 100.0, "min": 100}}, "EndTime": 1602329831.377634, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 98}, "StartTime": 1602329830.733406}
#
# [10/10/2020 11:37:11 INFO 140298610640704] #throughput_metric: host=algo-1, train throughput=140560.035166 records/second
# [10/10/2020 11:37:11 INFO 140298610640704] #quality_metric: host=algo-1, epoch=99, batch=0 train binary_classification_accuracy <score>=0.753
# [10/10/2020 11:37:11 INFO 140298610640704] #quality_metric: host=algo-1, epoch=99, batch=0 train binary_classification_cross_entropy <loss>=0.525001037598
# [10/10/2020 11:37:11 INFO 140298610640704] #quality_metric: host=algo-1, epoch=99, batch=0 train binary_f_1.000 <score>=0.780444444444
# [2020-10-10 11:37:12.018] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 200, "duration": 638, "num_examples": 91, "num_bytes": 5796480}
# [10/10/2020 11:37:12 INFO 140298610640704] #quality_metric: host=algo-1, epoch=99, train binary_classification_accuracy <score>=0.748230769231
# [10/10/2020 11:37:12 INFO 140298610640704] #quality_metric: host=algo-1, epoch=99, train binary_classification_cross_entropy <loss>=0.514655700013
# [10/10/2020 11:37:12 INFO 140298610640704] #quality_metric: host=algo-1, epoch=99, train binary_f_1.000 <score>=0.778279929935
# [10/10/2020 11:37:12 INFO 140298610640704] #quality_metric: host=algo-1, train binary_classification_accuracy <score>=0.748230769231
# [10/10/2020 11:37:12 INFO 140298610640704] #quality_metric: host=algo-1, train binary_classification_cross_entropy <loss>=0.514655700013
# [10/10/2020 11:37:12 INFO 140298610640704] #quality_metric: host=algo-1, train binary_f_1.000 <score>=0.778279929935
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 641.2148475646973, "sum": 641.2148475646973, "min": 641.2148475646973}}, "EndTime": 1602329832.019603, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1602329831.377423}
#
# [10/10/2020 11:37:12 INFO 140298610640704] #progress_metric: host=algo-1, completed 100 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Batches Since Last Reset": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Records Since Last Reset": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Total Batches Seen": {"count": 1, "max": 9101, "sum": 9101.0, "min": 9101}, "Total Records Seen": {"count": 1, "max": 9058000, "sum": 9058000.0, "min": 9058000}, "Max Records Seen Between Resets": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Reset Count": {"count": 1, "max": 101, "sum": 101.0, "min": 101}}, "EndTime": 1602329832.019851, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 99}, "StartTime": 1602329831.378355}
#
# [10/10/2020 11:37:12 INFO 140298610640704] #throughput_metric: host=algo-1, train throughput=141158.073183 records/second
# [10/10/2020 11:37:12 WARNING 140298610640704] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [10/10/2020 11:37:12 INFO 140298610640704] Pulling entire model from kvstore to finalize
# #metrics {"Metrics": {"finalize.time": {"count": 1, "max": 2.4080276489257812, "sum": 2.4080276489257812, "min": 2.4080276489257812}}, "EndTime": 1602329832.022552, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1602329832.019688}
#
# [10/10/2020 11:37:12 INFO 140298610640704] Saved checkpoint to "/tmp/tmpOUOoqp/state-0001.params"
# [2020-10-10 11:37:12.029] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/test", "epoch": 0, "duration": 68403, "num_examples": 1, "num_bytes": 64000}
# [2020-10-10 11:37:12.076] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/test", "epoch": 1, "duration": 46, "num_examples": 10, "num_bytes": 603520}
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 10, "sum": 10.0, "min": 10}, "Number of Batches Since Last Reset": {"count": 1, "max": 10, "sum": 10.0, "min": 10}, "Number of Records Since Last Reset": {"count": 1, "max": 9430, "sum": 9430.0, "min": 9430}, "Total Batches Seen": {"count": 1, "max": 10, "sum": 10.0, "min": 10}, "Total Records Seen": {"count": 1, "max": 9430, "sum": 9430.0, "min": 9430}, "Max Records Seen Between Resets": {"count": 1, "max": 9430, "sum": 9430.0, "min": 9430}, "Reset Count": {"count": 1, "max": 1, "sum": 1.0, "min": 1}}, "EndTime": 1602329832.076657, "Dimensions": {"Host": "algo-1", "Meta": "test_data_iter", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1602329832.029606}
#
# [10/10/2020 11:37:12 INFO 140298610640704] #test_score (algo-1) : ('binary_classification_accuracy', 0.6919406150583245)
# [10/10/2020 11:37:12 INFO 140298610640704] #test_score (algo-1) : ('binary_classification_cross_entropy', 0.5813552743177525)
# [10/10/2020 11:37:12 INFO 140298610640704] #test_score (algo-1) : ('binary_f_1.000', 0.7274603621352848)
# [10/10/2020 11:37:12 INFO 140298610640704] #quality_metric: host=algo-1, test binary_classification_accuracy <score>=0.691940615058
# [10/10/2020 11:37:12 INFO 140298610640704] #quality_metric: host=algo-1, test binary_classification_cross_entropy <loss>=0.581355274318
# [10/10/2020 11:37:12 INFO 140298610640704] #quality_metric: host=algo-1, test binary_f_1.000 <score>=0.727460362135
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 68513.31186294556, "sum": 68513.31186294556, "min": 68513.31186294556}, "setuptime": {"count": 1, "max": 51.301002502441406, "sum": 51.301002502441406, "min": 51.301002502441406}}, "EndTime": 1602329832.077689, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1602329832.022618}
#
# Training seconds: 119
# Billable seconds: 119

# %% [markdown]
# ### 6. Deploy model

# %%
fm_predictor = fm.deploy(instance_type='ml.t2.medium', initial_instance_count=1) 
# ml.c4.xlarge
# Out:
# -------------

# %%
def fm_serializer(data):
    js = {'instances': []}
    for row in data:
        js['instances'].append({'features': row.tolist()})
    #print js
    return json.dumps(js)

fm_predictor.content_type = 'application/json'
fm_predictor.serializer = fm_serializer
fm_predictor.deserializer = json_deserializer
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-14-b9441ceeb521> in <module>()
#       6     return json.dumps(js)
#       7
# ----> 8 fm_predictor.content_type = 'application/json'
#       9 fm_predictor.serializer = fm_serializer
#      10 fm_predictor.deserializer = json_deserializer
#
# NameError: name 'fm_predictor' is not defined

# %% [markdown]
# ### 7. Run predictions

# %%
result = fm_predictor.predict(X_test[1000:1010].toarray())
print(result)
print (Y_test[1000:1010])
